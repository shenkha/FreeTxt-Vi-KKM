# %%
# Please replace "YOUR_DATASET_PATH.csv" and "YOUR_STOPWORDS_PATH.txt" 
# with the actual paths to your dataset and stopwords files respectively.
# !python finetuneSA.py \
    --model_name "bkai-foundation-models/vietnamese-bi-encoder" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:7" \
    --output_dir_base "./fine_tuned_sa_manual_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:7
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_models/vietnamese-bi-encoder
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'bkai-foundation-models/vietnamese-bi-encoder' for fine-tuning...
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at bkai-foundation-models/vietnamese-bi-encoder and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Preparing dataloaders...
# Preprocessing texts for dataloaders...
# 100%|██████████████████████████████████| 47611/47611 [00:00<00:00, 70474.16it/s]
# Tokenizing texts...
# Train dataset size: 38088
# Validation dataset size: 9523
# ...

# %%
# !python finetuneSA.py \
    --model_name "uitnlp/visobert" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:3" \
    --output_dir_base "./fine_tuned_sa_manual_newPreprocess_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:7
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_models/visobert
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'uitnlp/visobert' for fine-tuning...
# /data/elo/.conda/envs/vifree-txt-3.10/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at uitnlp/visobert and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# ...

# %%
# !python finetuneSA.py \
    --model_name "vinai/phobert-base-v2" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:7" \
    --output_dir_base "./fine_tuned_sa_manual_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:7
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_models/phobert-base-v2
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'vinai/phobert-base-v2' for fine-tuning...
# config.json: 100%|█████████████████████████████| 678/678 [00:00<00:00, 4.13MB/s]
# vocab.txt: 100%|█████████████████████████████| 895k/895k [00:00<00:00, 1.24MB/s]
# bpe.codes: 100%|███████████████████████████| 1.14M/1.14M [00:00<00:00, 1.47MB/s]
# tokenizer.json: 100%|██████████████████████| 3.13M/3.13M [00:00<00:00, 4.23MB/s]
# pytorch_model.bin: 100%|█████████████████████| 540M/540M [00:11<00:00, 48.4MB/s]
# ...

# %%
# !python finetuneSA.py \
    --model_name "microsoft/Multilingual-MiniLM-L12-H384" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:7" \
    --output_dir_base "./fine_tuned_sa_manual_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:7
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_models/Multilingual-MiniLM-L12-H384
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'microsoft/Multilingual-MiniLM-L12-H384' for fine-tuning...
# tokenizer_config.json: 100%|█████████████████| 2.00/2.00 [00:00<00:00, 19.3kB/s]
# config.json: 100%|█████████████████████████████| 430/430 [00:00<00:00, 4.28MB/s]
# sentencepiece.bpe.model: 100%|█████████████| 5.07M/5.07M [00:01<00:00, 3.49MB/s]
# special_tokens_map.json: 100%|█████████████████| 150/150 [00:00<00:00, 1.01MB/s]
# pytorch_model.bin: 100%|█████████████████████| 471M/471M [00:16<00:00, 28.4MB/s]
# ...

# %%
# !python finetuneSA.py \
    --model_name "5CD-AI/Vietnamese-Sentiment-visobert" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:7" \
    --output_dir_base "./fine_tuned_sa_manual_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:7
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_models/Vietnamese-Sentiment-visobert
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model '5CD-AI/Vietnamese-Sentiment-visobert' for fine-tuning...
# Preparing dataloaders...
# Preprocessing texts for dataloaders...
# 100%|█████████████████████████████████| 47611/47611 [00:00<00:00, 120957.71it/s]
# Tokenizing texts...
# Train dataset size: 38088
# Validation dataset size: 9523
# Starting fine-tuning of 5CD-AI/Vietnamese-Sentiment-visobert for 5 epochs...
#
# Epoch 1/5
# Training: 100%|█████████████████████████████| 1587/1587 [05:54<00:00,  4.48it/s]
# Average training loss: 0.5322
# Evaluating on validation set...
# Evaluating: 100%|█████████████████████████████| 397/397 [00:31<00:00, 12.71it/s]
# Validation Accuracy: 0.7979
# Validation Classification Report:
# ...

# %%
# !python finetuneSA.py \
    --model_name "uitnlp/visobert" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:6" \
    --output_dir_base "./fine_tuned_sa_manual_newPreprocess_models" \
    --num_labels 3 \
    --max_seq_length 1024 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:6
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_newPreprocess_models/visobert
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'uitnlp/visobert' for fine-tuning...
# /data/elo/.conda/envs/vifree-txt-3.10/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at uitnlp/visobert and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# ...

# %%
# !python finetuneSA.py \
    --model_name "bkai-foundation-models/vietnamese-bi-encoder" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:7" \
    --output_dir_base "./fine_tuned_sa_manual_newPreprocess_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:7
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_newPreprocess_models/vietnamese-bi-encoder
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'bkai-foundation-models/vietnamese-bi-encoder' for fine-tuning...
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at bkai-foundation-models/vietnamese-bi-encoder and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Preparing dataloaders...
# Preprocessing texts for dataloaders...
# 100%|███████████████████████████████████| 47611/47611 [00:45<00:00, 1039.93it/s]
# Tokenizing texts...
# Train dataset size: 38088
# Validation dataset size: 9523
# ...

# %%
# !python finetuneSA.py \
    --model_name "uitnlp/visobert" \
    --dataset_path "sentiment_analysis_dataset.csv" \
    --stopwords_path "vietnamese-stopwords.txt" \
    --device "cuda:6" \
    --output_dir_base "./fine_tuned_sa_manual_newPreprocess_models" \
    --num_labels 3 \
    --max_seq_length 128 \
    --epochs 5 \
    --learning_rate 2e-5 \
    --batch_size 24
# Out:
# Using device: cuda:6
# Successfully loaded 1942 Vietnamese stopwords from vietnamese-stopwords.txt.
# Fine-tuned model will be saved to: ./fine_tuned_sa_manual_newPreprocess_models/visobert
# Loading dataset from: sentiment_analysis_dataset.csv
# Loading base model 'uitnlp/visobert' for fine-tuning...
# /data/elo/.conda/envs/vifree-txt-3.10/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at uitnlp/visobert and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# ...
