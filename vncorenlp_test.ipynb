# %%
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.2.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.2.jar vncorenlp/
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# Out:
# --2025-06-03 07:54:03--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.2.jar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27412703 (26M) [application/octet-stream]
# Saving to: ‘VnCoreNLP-1.2.jar’
#
# VnCoreNLP-1.2.jar   100%[===================>]  26.14M  1.09MB/s    in 23s
#
# 2025-06-03 07:54:28 (1.15 MB/s) - ‘VnCoreNLP-1.2.jar’ saved [27412703/27412703]
#
# --2025-06-03 07:54:28--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# ...

# %%
from vncorenlp import VnCoreNLP

vncorenlp = VnCoreNLP("/home/ubuntu/khang.lg/work/FreeTxt-Vi-KKM/vncorenlp/VnCoreNLP-1.2.jar", annotators="wseg", max_heap_size='-Xmx500m')

# %%
text = "hello, hòa thuận, cuộc sống mà. Ông Nguyễn Khắc Chúc  đang làm việc tại Đại học Quốc gia Hà Nội. Bà Lan, vợ ông Chúc, cũng làm việc tại đây."

word_segmented_text = vncorenlp.tokenize(text)
print(type(word_segmented_text))
print(word_segmented_text)
# Out:
# <class 'list'>
# [['hello', ',', 'hoà_thuận', ',', 'cuộc_sống', 'mà', '.'], ['Ông', 'Nguyễn_Khắc_Chúc', 'đang', 'làm_việc', 'tại', 'Đại_học', 'Quốc_gia', 'Hà_Nội', '.'], ['Bà', 'Lan', ',', 'vợ', 'ông', 'Chúc', ',', 'cũng', 'làm_việc', 'tại', 'đây', '.']]

# %%
import py_vncorenlp
py_vncorenlp.download_model(save_dir='/home/ubuntu/khang.lg/work/FreeTxt-Vi-KKM/pyvncorenlp')
# Out:
# --2025-06-09 11:15:09--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.2.jar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27412703 (26M) [application/octet-stream]
# Saving to: ‘VnCoreNLP-1.2.jar.1’
#
#      0K .......... .......... .......... .......... ..........  0%  851K 31s
#     50K .......... .......... .......... .......... ..........  0% 1.09M 28s
#    100K .......... .......... .......... .......... ..........  0% 4.55M 20s
#    150K .......... .......... .......... .......... ..........  0% 1.63M 19s
#    200K .......... .......... .......... .......... ..........  0% 4.36M 17s
#    250K .......... .......... .......... .......... ..........  1% 4.73M 15s
# ...

# %%
import py_vncorenlp
model = py_vncorenlp.VnCoreNLP(save_dir='/home/ubuntu/khang.lg/work/FreeTxt-Vi-KKM/pyvncorenlp')
# Out:
# 2025-06-09 11:31:48 INFO  WordSegmenter:24 - Loading Word Segmentation model
# 2025-06-09 11:31:48 INFO  PosTagger:23 - Loading POS Tagging model
# 2025-06-09 11:31:51 INFO  NerRecognizer:34 - Loading NER model
# 2025-06-09 11:32:03 INFO  DependencyParser:32 - Loading Dependency Parsing model

# %%
text = "Ông Nguyễn Khắc Chúc  đang làm việc tại Đại học Quốc gia Hà Nội. Bà Lan, vợ ông Chúc, cũng làm việc tại đây."
output = model.word_segment(text)
print(output)
# Out:
# ['Ông Nguyễn_Khắc_Chúc đang làm_việc tại Đại_học Quốc_gia Hà_Nội .', 'Bà Lan , vợ ông Chúc , cũng làm_việc tại đây .']

# %%
output = model.annotate_text(text)
output
# Out:
# {0: [{'index': 1,
#    'wordForm': 'Ông',
#    'posTag': 'Nc',
#    'nerLabel': 'O',
#    'head': 4,
#    'depLabel': 'sub'},
#   {'index': 2,
#    'wordForm': 'Nguyễn_Khắc_Chúc',
#    'posTag': 'Np',
#    'nerLabel': 'B-PER',
#    'head': 1,
#    'depLabel': 'nmod'},
#   {'index': 3,
#    'wordForm': 'đang',
#    'posTag': 'R',
#    'nerLabel': 'O',
#    'head': 4,
#    'depLabel': 'adv'},
#   {'index': 4,
#    'wordForm': 'làm_việc',
#    'posTag': 'V',
#    'nerLabel': 'O',
#    'head': 0,
#    'depLabel': 'root'},
#   {'index': 5,
#    'wordForm': 'tại',
#    'posTag': 'E',
#    'nerLabel': 'O',
#    'head': 4,
#    'depLabel': 'loc'},
#   {'index': 6,
#    'wordForm': 'Đại_học',
#    'posTag': 'N',
#    'nerLabel': 'B-ORG',
#    'head': 5,
#    'depLabel': 'pob'},
#   {'index': 7,
#    'wordForm': 'Quốc_gia',
#    'posTag': 'N',
#    'nerLabel': 'I-ORG',
#    'head': 6,
#    'depLabel': 'nmod'},
#   {'index': 8,
#    'wordForm': 'Hà_Nội',
#    'posTag': 'Np',
# ...

# %%
import
# Out:
#   Cell In[14], line 1
#     import
#           ^
# SyntaxError: invalid syntax
